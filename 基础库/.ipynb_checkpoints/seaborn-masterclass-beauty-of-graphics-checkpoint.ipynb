# %% [markdown]
# <div style="background-color: #ffffcc; padding: 20px; border-radius: 10px;">
#     <h1 style="text-align: center; font-size: 32px;">📊 Welcome to the Data Viz With Seaborn Notebook! 📈✨</h1>
#     <p style="text-align: center; font-size: 18px;">
#         Hey there, data enthusiasts! 👋 Welcome to this interactive notebook dedicated to Seaborn, the magical Python library for data visualization! 🌈
#     </p>
#     <p style="text-align: center; font-size: 18px;">
#         In this notebook, we'll embark on a visual journey, exploring Seaborn's vast array of plotting functions and creating captivating visualizations. Whether you're a data analyst, scientist, or enthusiast, we've got you covered! 🚀
#     </p>
#     <p style="text-align: center; font-size: 18px;">
#         Let's dive right in and uncover the beauty of Seaborn together! 🎨📈
#     </p>
# </div>

# %% [markdown]
# <h2 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Disclaimer </h2>

# %% [markdown]
# <p style="text-align: center; font-size: 18px; background-color: #ffffcc">
#        This notebook aims to provide a comprehensive guide to Seaborn data visualization with a focus on various essential and commonly used plots. However, please note that Seaborn offers a wide range of visualization functions, and this notebook may not cover all available graph types.
#     </p>

# %% [markdown]
# <h2 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">🛠Importing Necessary Libraries✨</h2>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h2 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">📁 Sample Datasets 📁 </h2>

# %%
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')  
exercise = sns.load_dataset('exercise')  
titanic = sns.load_dataset('titanic')  
fmri = sns.load_dataset('fmri')

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Scatter Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information : A scatter plot showing the relationship between sepal length and sepal width for different iris flower species. The plot can help identify potential patterns or clusters among iris species based on these two attributes.</p>

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris)
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Line Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information : A line plot depicting the fMRI signal response over time for a specific subject. This plot helps visualize the time-dependent changes in the subject's brain activity captured through fMRI scans.</p>

# %%
sns.lineplot(x='timepoint', y='signal', data=fmri)
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Bar Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information :  A bar plot illustrating the total bill amount for each day of the week based on customer tips. The plot allows us to compare the total bill amounts on different days and identify any significant </p>

# %%
sns.barplot(x='day', y='total_bill', data=tips)
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Violin Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information : A violin plot visualizing the distribution of data, particularly showcasing the kernel density estimation along with the box plot. It provides insights into the data's density, skewness, and presence of multiple modes.</p>

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Histogram Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information : A histogram displaying the distribution of total bill amounts in the sample dataset. This plot gives an overview of how the total bill amounts are distributed and helps identify common ranges.</p>

# %%
sns.histplot(x='total_bill', data=tips)
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Pair Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information : A pair plot showing the relationship between various attributes of iris flowers, colored by species. This plot enables us to visualize the correlations between different attributes and how they vary across different iris species.</p>

# %%
sns.pairplot(iris, hue='species')
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Heat Map 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information : A heatmap visualizing the correlation between different attributes of iris flowers. This heatmap provides a color-coded representation of attribute correlations, making it easier to identify strong or weak relationships.</p>

# %%
sns.heatmap(iris.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Joint Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information : A joint plot highlighting the relationship between total bill and tip amount in the sample dataset. This plot combines a scatter plot and histograms to show the distribution of both variables and their correlation.</p>

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Regression/Reg Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information :  A regression plot displaying the linear relationship between total bill and tip in the dataset. This plot helps visualize the trend and strength of the linear relationship between the two variables.</p>

# %%
sns.regplot(x='total_bill', y='tip', data=tips)
plt.show()

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Categorical Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information : A count plot representing the frequency of categories in the sample dataset. This plot displays the occurrence of each category, helping identify the most and least common categories.</p>

# %%
sns.catplot(x='sex', y='total_bill', hue='time', data=tips, kind='bar')
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Distribution Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information : A distribution plot illustrating the spread of data across a single variable. It provides valuable insights into the data's central tendency, variability, and skewness.</p>

# %%
sns.displot(tips['total_bill'], kde=True)
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Swarm Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information :A swarm plot visualizing the distribution of scores for different students. This plot shows individual data points and their distribution, making it useful for comparing scores across students.</p>

# %%
students = ['Alice', 'Bob', 'Charlie', 'David', 'Eva']
scores = np.random.randint(50, 100, size=len(students))
sns.swarmplot(x=students, y=scores)
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 FaceGrid Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information : A facet grid with scatter plots of total bill and tip amount, grouped by gender and meal time. This grid allows us to examine how total bill and tip amount vary based on both gender and meal time.</p>

# %%
g = sns.FacetGrid(tips, col='sex', row='time', margin_titles=True)
g.map_dataframe(sns.scatterplot, x='total_bill', y='tip')
g.set_axis_labels('Total Bill ($)', 'Tip ($)')
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Kde Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information : A KDE plot displaying the estimated probability density function of a random variable. This plot provides a smooth representation of the underlying probability distribution.</p>

# %%
data = np.random.normal(loc=0, scale=1, size=1000)

sns.kdeplot(data)
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <h4 style="text-align: center; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> 📈📊 Point Plot 📈📊 </h4>

# %% [markdown]
# <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Information : A point plot illustrating data points on a numeric scale. This plot is useful for visualizing individual data points and their positions on a numeric axis.</p>

# %%
x_vals = [1, 2, 3, 4, 5]
y_vals = [2, 4, 1, 3, 5]

sns.pointplot(x=x_vals, y=y_vals)
plt.show()
# Out:
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# E:\Geo_Data\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# <h5 style="text-align: left; font-size: 32px; background-color: #ffffcc; padding: 10px; border-radius: 10px;"> Conclusion :</h5>
#     <p style="text-align: left; font-size: 20px; background-color: #ffffcc; padding: 10px; border-radius: 10px;">Congratulations! 🎉 You have completed the exciting journey of mastering Seaborn and creating stunning visualizations. I hope you found this notebook informative and engaging.
# </p>

# %% [markdown]
# <p style="text-align: left; font-size: 32px; background-color: #d1e189; padding: 10px; border-radius: 10px;"> Thank you for exploring this notebook! If you enjoyed it and found value in the content, please consider giving it an upvote ⬆️. Your support means a lot to me and encourages me to create more helpful notebooks for the community.
# </p>
